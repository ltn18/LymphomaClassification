# %% [markdown]
# <a href="https://colab.research.google.com/github/ltn18/LymphomaClassification/blob/main/make_output_densenet_cmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
print(sklearn.__version__)
import torch
print(torch.__version__)
import argparse
print(argparse.__version__)
import numpy
print(numpy.__version__)
import cv2
print(cv2.__version__)
import torchvision
print(torchvision.__version__)
# Out:
# 0.22.2.post1
# 1.8.1+cu101
# 1.1
# 1.19.5
# 4.1.2
# 0.9.1+cu101

# %%
# v3.classification
# 3/12/2018

import argparse
import os
import glob
import numpy as np
import cv2
import torch
import sklearn.feature_extraction.image

from torchvision.models import DenseNet

# %%
#-----helper function to split data into batches
def divide_batch(l, n): 
    for i in range(0, l.shape[0], n):  
        yield l[i:i + n,::]

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data

# %%
# ----- parse command line arguments
parser = argparse.ArgumentParser(description='Make output for entire image using Unet')
parser.add_argument('input_pattern',
                    help="input filename pattern. try: *.png, or tsv file containing list of files to analyze",
                    nargs="*")

parser.add_argument('-p', '--patchsize', help="patchsize, default 256", default=256, type=int)
parser.add_argument('-s', '--batchsize', help="batchsize for controlling GPU memory usage, default 10", default=10, type=int)
parser.add_argument('-o', '--outdir', help="outputdir, default ./output/", default="./output/", type=str)
parser.add_argument('-r', '--resize', help="resize factor 1=1x, 2=2x, .5 = .5x", default=1, type=float)
parser.add_argument('-m', '--model', help="model", default="best_model.pth", type=str)
parser.add_argument('-i', '--gpuid', help="id of gpu to use", default=0, type=int)
parser.add_argument('-f', '--force', help="force regeneration of output even if it exists", default=False,
                    action="store_true")
parser.add_argument('-b', '--basepath',
                    help="base path to add to file names, helps when producing data using tsv file as input",
                    default="", type=str)

# args = parser.parse_args()-p 224 -s 1 -m lymphoma_densenet_best_model.pth
args = parser.parse_args(["*.tif","-p256","-m/gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/lymphoma_densenet_best_model.pth","-b/gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/**"] )

if not (args.input_pattern):
    parser.error('No images selected with input pattern')

OUTPUT_DIR = args.outdir
resize = args.resize

batch_size = args.batchsize
patch_size = args.patchsize
stride_size = patch_size//2

# %%
# ----- load network
device = torch.device(args.gpuid if args.gpuid!=-2 and torch.cuda.is_available() else 'cpu')

# %%
checkpoint = torch.load(args.model, map_location=lambda storage, loc: storage)

 #load checkpoint to CPU and then put to device https://discuss.pytorch.org/t/saving-and-loading-torch-models-on-2-machines-with-different-number-of-gpu-devices/6666

# %%
model = DenseNet(growth_rate=checkpoint["growth_rate"], block_config=checkpoint["block_config"],
                 num_init_features=checkpoint["num_init_features"], bn_size=checkpoint["bn_size"],
                 drop_rate=checkpoint["drop_rate"], num_classes=checkpoint["num_classes"]).to(device)

model.load_state_dict(checkpoint["model_dict"])
model.eval()

print(f"total params: \t{sum([np.prod(p.size()) for p in model.parameters()])}")
# Out:
# total params: 	415683

# %%
# ----- get file list

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

files = []
basepath = args.basepath  #

basepath = basepath + os.sep if len(
    basepath) > 0 else ""  # if the user supplied a different basepath, make sure it ends with an os.sep


if len(args.input_pattern) > 1:  # bash has sent us a list of files
    files = args.input_pattern
elif args.input_pattern[0].endswith("tsv"):  # user sent us an input file
    # load first column here and store into files

    with open(args.input_pattern[0], 'r') as f:
        for line in f:
            if line[0] == "#":
                continue
            files.append(basepath + line.strip().split("\t")[0])
else:  # user sent us a wildcard, need to use glob to find files
    files = glob.glob(args.basepath +"/"+ args.input_pattern[0])
    
# ------ work on files
# Out:
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/**

# %%
for fname in files:
    
    fname = fname.strip()
    print(fname)
    newfname_class = "%s/%s_class.png" % (OUTPUT_DIR, os.path.basename(fname)[0:-4])
    
    print(f"working on file: \t {fname}")

    # if not args.force and os.path.exists(newfname_class):
    #     print("Skipping as output file exists")
    #     continue
    #
    # cv2.imwrite(newfname_class, np.zeros(shape=(1, 1)))

    
    io = cv2.cvtColor(cv2.imread(fname),cv2.COLOR_BGR2RGB)
    io = cv2.resize(io, (0, 0), fx=args.resize, fy=args.resize)

    io_shape_orig = np.array(io.shape)
    
    #add half the stride as padding around the image, so that we can crop it away later
    io = np.pad(io, [(stride_size//2, stride_size//2), (stride_size//2, stride_size//2), (0, 0)], mode="reflect")
    
    io_shape_wpad = np.array(io.shape)
    
    #pad to match an exact multiple of unet patch size, otherwise last row/column are lost
    npad0 = int(np.ceil(io_shape_wpad[0] / patch_size) * patch_size - io_shape_wpad[0])
    npad1 = int(np.ceil(io_shape_wpad[1] / patch_size) * patch_size - io_shape_wpad[1])

    io = np.pad(io, [(0, npad0), (0, npad1), (0, 0)], mode="constant")

    arr_out = sklearn.feature_extraction.image.extract_patches(io,(patch_size,patch_size,3),stride_size)
    arr_out_shape = arr_out.shape
    arr_out = arr_out.reshape(-1,patch_size,patch_size,3)

    #in case we have a large network, lets cut the list of tiles into batches
    output = np.zeros((0,checkpoint["num_classes"]))
    for batch_arr in divide_batch(arr_out,batch_size):
        
        arr_out_gpu = torch.from_numpy(batch_arr.transpose(0, 3, 1, 2) / 255).type('torch.FloatTensor').to(device)

        # ---- get results
        output_batch = model(arr_out_gpu)

        # --- pull from GPU and append to rest of output 
        output_batch = output_batch.detach().cpu().numpy()
        output = np.append(output,output_batch,axis=0)


    tileclass = np.argmax(output, axis=1)
    predc,predccounts=np.unique(tileclass, return_counts=True)
    for c,cc in zip(predc,predccounts):
        print(f"class/count: \t{c}\t{cc}")

    print(f"predicted class:\t{predc[np.argmax(predccounts)]}")
# Out:
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_001.tif
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function extract_patches is deprecated; The function feature_extraction.image.extract_patches has been deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(msg, category=FutureWarning)
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_006.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_009.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-901-R1_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_001.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_002.tif
# class/count: 	0	14
# class/count: 	2	85
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_003.tif
# class/count: 	0	7
# class/count: 	2	92
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_006.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_008.tif
# class/count: 	0	6
# class/count: 	2	93
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_009.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_010.tif
# class/count: 	0	4
# class/count: 	2	95
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_011.tif
# class/count: 	0	7
# class/count: 	2	92
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_012.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_013.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_013.tif
# class/count: 	0	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_014.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_014.tif
# class/count: 	0	7
# class/count: 	2	92
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_015.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-768_015.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_001.tif
# class/count: 	1	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_005.tif
# class/count: 	1	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_006.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_009.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_010.tif
# class/count: 	0	2
# class/count: 	1	27
# class/count: 	2	70
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4967-R2_011.tif
# class/count: 	1	4
# class/count: 	2	95
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_001.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_003.tif
# class/count: 	0	11
# class/count: 	2	88
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_004.tif
# class/count: 	0	30
# class/count: 	2	69
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_006.tif
# class/count: 	0	3
# class/count: 	2	96
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_007.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_009.tif
# class/count: 	0	40
# class/count: 	1	57
# class/count: 	2	2
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_011.tif
# class/count: 	0	18
# class/count: 	2	81
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-4525-R4_012.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_001.tif
# class/count: 	0	4
# class/count: 	2	95
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_002.tif
# class/count: 	0	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_004.tif
# class/count: 	0	31
# class/count: 	2	68
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_005.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_006.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_008.tif
# class/count: 	0	48
# class/count: 	2	51
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_009.tif
# class/count: 	0	61
# class/count: 	2	38
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-3077-R2_011.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_001.tif
# class/count: 	0	16
# class/count: 	2	83
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_002.tif
# class/count: 	0	25
# class/count: 	2	74
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_003.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_004.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_006.tif
# class/count: 	0	10
# class/count: 	2	89
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_007.tif
# class/count: 	0	12
# class/count: 	2	87
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_009.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_010.tif
# class/count: 	0	7
# class/count: 	2	92
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-04-6010-R3_011.tif
# class/count: 	0	12
# class/count: 	2	87
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_001.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_002.tif
# class/count: 	0	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_004.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_006.tif
# class/count: 	0	53
# class/count: 	2	46
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_007.tif
# class/count: 	0	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_008.tif
# class/count: 	0	85
# class/count: 	1	1
# class/count: 	2	13
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_009.tif
# class/count: 	0	66
# class/count: 	1	10
# class/count: 	2	23
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_010.tif
# class/count: 	0	10
# class/count: 	2	89
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_011.tif
# class/count: 	0	6
# class/count: 	2	93
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_012.tif
# class/count: 	0	14
# class/count: 	2	85
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_013.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_013.tif
# class/count: 	0	65
# class/count: 	2	34
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_014.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-1374_014.tif
# class/count: 	0	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_001.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_006.tif
# class/count: 	0	5
# class/count: 	2	94
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_009.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_011.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_012.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_013.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_013.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_014.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_014.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_015.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-3362-R2_015.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_001.tif
# class/count: 	1	4
# class/count: 	2	95
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_003.tif
# class/count: 	1	8
# class/count: 	2	91
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_006.tif
# class/count: 	1	1
# class/count: 	2	98
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_007.tif
# class/count: 	1	5
# class/count: 	2	94
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_009.tif
# class/count: 	1	21
# class/count: 	2	78
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_011.tif
# class/count: 	1	25
# class/count: 	2	74
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-5326-R1_012.tif
# class/count: 	0	1
# class/count: 	1	10
# class/count: 	2	88
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_002.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_003.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_004.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_005.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_006.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_007.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_008.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_009.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_010.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_011.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/MCL/sj-05-4179-R1_012.tif
# class/count: 	2	99
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_001.tif
# class/count: 	0	4
# class/count: 	1	95
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_002.tif
# class/count: 	0	6
# class/count: 	1	93
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_003.tif
# class/count: 	0	4
# class/count: 	1	87
# class/count: 	2	8
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_004.tif
# class/count: 	0	45
# class/count: 	1	44
# class/count: 	2	10
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_005.tif
# class/count: 	0	88
# class/count: 	1	10
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_006.tif
# class/count: 	0	97
# class/count: 	2	2
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_007.tif
# class/count: 	0	84
# class/count: 	2	15
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_008.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_009.tif
# class/count: 	0	73
# class/count: 	1	26
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-588-R1_010.tif
# class/count: 	0	2
# class/count: 	1	97
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_001.tif
# class/count: 	0	78
# class/count: 	1	21
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_002.tif
# class/count: 	0	34
# class/count: 	1	65
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_003.tif
# class/count: 	0	32
# class/count: 	1	67
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_004.tif
# class/count: 	0	2
# class/count: 	1	96
# class/count: 	2	1
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_005.tif
# class/count: 	0	22
# class/count: 	1	77
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_006.tif
# class/count: 	0	18
# class/count: 	1	81
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_007.tif
# class/count: 	0	2
# class/count: 	1	97
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_008.tif
# class/count: 	0	58
# class/count: 	1	40
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_009.tif
# class/count: 	0	52
# class/count: 	1	47
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_010.tif
# class/count: 	0	14
# class/count: 	1	85
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-1467-R1_011.tif
# class/count: 	0	1
# class/count: 	1	87
# class/count: 	2	11
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_001.tif
# class/count: 	0	1
# class/count: 	1	98
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_002.tif
# class/count: 	1	98
# class/count: 	2	1
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_003.tif
# class/count: 	1	83
# class/count: 	2	16
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_004.tif
# class/count: 	1	81
# class/count: 	2	18
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_005.tif
# class/count: 	0	3
# class/count: 	1	70
# class/count: 	2	26
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_006.tif
# class/count: 	1	97
# class/count: 	2	2
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_007.tif
# class/count: 	1	96
# class/count: 	2	3
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_008.tif
# class/count: 	1	78
# class/count: 	2	21
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_009.tif
# class/count: 	1	71
# class/count: 	2	28
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-4881-R3_010.tif
# class/count: 	1	97
# class/count: 	2	2
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-5311-R1_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-5311-R1_001.tif
# class/count: 	1	76
# class/count: 	2	23
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/FL/sj-05-5311-R1_002.tif
# ...
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_009.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_010.tif
# class/count: 	0	68
# class/count: 	1	31
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-03-2810_011.tif
# class/count: 	0	98
# class/count: 	1	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_001.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_002.tif
# class/count: 	0	98
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_003.tif
# class/count: 	0	87
# class/count: 	1	1
# class/count: 	2	11
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_004.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_005.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_006.tif
# class/count: 	0	86
# class/count: 	1	7
# class/count: 	2	6
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_007.tif
# class/count: 	0	81
# class/count: 	1	14
# class/count: 	2	4
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_008.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_009.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_010.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-1396-R3_011.tif
# class/count: 	0	89
# class/count: 	1	10
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_001.tif
# class/count: 	0	65
# class/count: 	2	34
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_002.tif
# class/count: 	0	90
# class/count: 	2	9
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_003.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_004.tif
# class/count: 	0	95
# class/count: 	2	4
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_005.tif
# class/count: 	0	44
# class/count: 	2	55
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_006.tif
# class/count: 	0	98
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_007.tif
# class/count: 	0	97
# class/count: 	2	2
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_008.tif
# class/count: 	0	98
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_009.tif
# class/count: 	0	98
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_010.tif
# class/count: 	0	46
# class/count: 	2	53
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_011.tif
# class/count: 	0	2
# class/count: 	2	97
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3165_012.tif
# class/count: 	0	89
# class/count: 	2	10
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_002.tif
# class/count: 	0	93
# class/count: 	2	6
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_003.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_004.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_005.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_006.tif
# class/count: 	0	76
# class/count: 	2	23
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_007.tif
# class/count: 	0	97
# class/count: 	2	2
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_008.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_009.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_010.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_011.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_012.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_012.tif
# class/count: 	0	86
# class/count: 	2	13
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_013.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_013.tif
# class/count: 	0	95
# class/count: 	2	4
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_014.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_014.tif
# class/count: 	0	96
# class/count: 	2	3
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_015.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-5269-R10_015.tif
# class/count: 	0	42
# class/count: 	2	57
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_001.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_001.tif
# class/count: 	0	42
# class/count: 	1	45
# class/count: 	2	12
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_002.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_002.tif
# class/count: 	0	48
# class/count: 	1	45
# class/count: 	2	6
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_003.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_003.tif
# class/count: 	0	62
# class/count: 	1	31
# class/count: 	2	6
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_004.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_004.tif
# class/count: 	0	30
# class/count: 	1	69
# predicted class:	1
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_005.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_005.tif
# class/count: 	0	74
# class/count: 	1	19
# class/count: 	2	6
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_006.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_006.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_007.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_007.tif
# class/count: 	0	97
# class/count: 	1	2
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_008.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_008.tif
# class/count: 	0	99
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_009.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_009.tif
# class/count: 	0	97
# class/count: 	1	1
# class/count: 	2	1
# predicted class:	0
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_010.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_010.tif
# class/count: 	0	11
# class/count: 	1	4
# class/count: 	2	84
# predicted class:	2
# /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_011.tif
# working on file: 	 /gdrive/My Drive/Colab Notebooks/PytorchDigitalPathology/classification_lymphoma_densenet/data/CLL/sj-05-3344_011.tif
# class/count: 	0	85
# class/count: 	1	13
# class/count: 	2	1
# predicted class:	0
